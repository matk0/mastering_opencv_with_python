# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt 
import matplotlib
# %matplotlib inline

# %%
image = cv2.imread('Apollo-8-Launch.jpg', cv2.IMREAD_COLOR)

plt.figure(figsize=(10,10))
plt.imshow(image)
print(image.shape)
# Out:
# (480, 600, 3)

# %%
yellow = (0, 255, 255)
red = (0, 0, 255)
magenta = (255, 0, 255)
green = (0, 255, 0)

# %%
image_line = image.copy()

image_line = cv2.line(image_line, (0, 445), (450, 465), yellow, thickness=3, lineType=cv2.LINE_8)

plt.figure(figsize=(10,10))
plt.imshow(image_line[:, :, ::-1])

# %%
image_line_aa = image.copy()

image_line_aa = cv2.line(image_line_aa, (0, 445), (450, 465), yellow, thickness=3, lineType=cv2.LINE_AA)

plt.figure(figsize=(10,10))
plt.imshow(image_line_aa[:, :, ::-1])

# %%
image_circle = image.copy()

image_circle = cv2.circle(image_circle, (195, 55), 20, red, thickness=3, lineType=cv2.LINE_AA)

plt.figure(figsize=(10,10))
plt.imshow(image_circle[:, :, ::-1])

# %%
image_rectangle = image.copy()

image_rectangle = cv2.rectangle(image_rectangle, (300, 150), (480, 420), magenta, thickness=3, lineType=cv2.LINE_AA)

plt.figure(figsize=(10,10))
plt.imshow(image_rectangle[:, :, ::-1])

# %%
image_text = image.copy()

text = 'Apollo 8'
font = cv2.FONT_HERSHEY_SIMPLEX
font_scale = 1.5
thickness = 3

image_text = cv2.putText(image_text, text, (45, 30), font, font_scale, green, thickness, lineType=cv2.LINE_AA)

plt.figure(figsize=(10,10))
plt.imshow(image_text[:, :, ::-1])
